# %%
import pandas as pd
df = pd.read_csv(r"D:\MY DATA\GitHub ASSIGNMENTS\pandas\beginner\IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df = pd.read_json(r"D:\MY DATA\GitHub ASSIGNMENTS\pandas\beginner\purchases.json")
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %% [markdown]
# # Using SQL

# %%
import sqlite3
con = sqlite3.connect(r"D:\MY DATA\GitHub ASSIGNMENTS\pandas\beginner\database.db")
df = pd.read_sql_query("SELECT * FROM purchases", con)
df
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %% [markdown]
# # Coversion

# %%
df.to_csv('new_purchase.csv')
df.to_json('new_purchase.json')
df.to_csv('new_purchase_without_index.csv', index=False)
#df.to_sql('new_purchase.sql')

# %% [markdown]
# # Important Operations

# %%
movies_df = pd.read_csv(r"D:\MY DATA\GitHub ASSIGNMENTS\pandas\beginner\IMDB-Movie-Data.csv", index_col = "Title")
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.head()      #by deafult shows first 5 rows
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
movies_df.tail()   #by deafult shows last 5 rows
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
movies_df.tail(10)
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Taare Zameen Par                 992        Drama,Family,Music
# Take Me Home Tonight             993      Comedy,Drama,Romance
# Resident Evil: Afterlife         994   Action,Adventure,Horror
# Project X                        995                    Comedy
# Secret in Their Eyes             996       Crime,Drama,Mystery
# Hostel: Part II                  997                    Horror
# Step Up 2: The Streets           998       Drama,Music,Romance
# Search Party                     999          Adventure,Comedy
# Nine Lives                      1000     Comedy,Family,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
# Taare Zameen Par                An eight-year-old boy is thought to be a lazy ...
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
# Rank                  1000 non-null int64
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movies_df.shape
# Out:
# (1000, 11)

# %%
temp_df = movies_df.append(movies_df)
temp_df.shape                          #duplicate rows
# Out:
# (2000, 11)

# %%
remove_dup_df = temp_df.drop_duplicates()   # drop_duplicates() removes duplicates
movies_df.shape                             # with new variable
# Out:
# (1000, 11)

# %%
temp_df.drop_duplicates(inplace = True)
temp_df.shape                          #remove duplicates using same variable
# Out:
# (1000, 11)

# %%
# first: (default) Drop duplicates except for the first occurance
# last: Drop duplicates except for the last occurance
# False: Drop all duplicates

# %%
temp_df.drop_duplicates(inplace = True, keep = "first")
temp_df.shape
# Out:
# (1000, 11)

# %%
temp_df = movies_df.append(movies_df)          #make a new copy
temp_df.drop_duplicates(inplace = True, keep = False)
temp_df.shape
# Out:
# (0, 11)

# %% [raw]
# movies_df.rename(columns = {'Runtime (Minutes)': "Runtime",
#                            "Revenue (Millions)": "Revenue_millions"}
#                             , inplace = True)
# movies_df.columns

# %%
# Or

movies_df.columns = ['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
       'Rating', 'Votes', 'Revenue_millions', 'Metascore']
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue_millions', 'Metascore'],
#       dtype='object')

# %%
# Or

movies_df.columns = [col.lower() for col in movies_df]
movies_df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
movies_df.isnull()       #shows where are null values
# Out:
#                           rank  genre  description  director  actors   year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
movies_df.isnull().sum()    #Gives no. of null values
# Out:
# rank                  0
# genre                 0
# description           0
# director              0
# actors                0
# year                  0
# runtime               0
# rating                0
# votes                 0
# revenue_millions    128
# metascore            64
# dtype: int64

# %%
movies_df.dropna()       # removes rows which has null values
                         #this is not generally used bcoz of loss of too much data
                         # by default axis = 0 i.e. drop rows
# Out:
#                           rank                     genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.dropna(axis = 1)        # axis = 0 i.e. drop columns. It drops revenue_millions and metascore as they have null values.
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# # Filling null values

# %%
# Imputation: it is technique used keep data by filling null values

revenue = movies_df["revenue_millions"]
print(revenue)

revenue_mean = revenue.mean()
revenue_mean
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: revenue_millions, Length: 1000, dtype: float64
# 82.95637614678897

# %%
x = revenue.fillna(revenue_mean, inplace = True)

# %%
movies_df.isnull()
# Out:
#                           rank  genre  description  director  actors   year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
movies_df.isnull().sum()
# Out:
# rank                 0
# genre                0
# description          0
# director             0
# actors               0
# year                 0
# runtime              0
# rating               0
# votes                0
# revenue_millions     0
# metascore           64
# dtype: int64

# %%
# Fill null values of metascore

# %%
metascore = movies_df["metascore"]

metascore_mean = metascore.mean()
metascore_mean
# Out:
# 58.98504273504273

# %%
metascore.fillna(metascore_mean, inplace = True)

# %%
movies_df.isnull()
# Out:
#                           rank  genre  description  director  actors   year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
movies_df.isnull().sum()
# Out:
# rank                0
# genre               0
# description         0
# director            0
# actors              0
# year                0
# runtime             0
# rating              0
# votes               0
# revenue_millions    0
# metascore           0
# dtype: int64

# %%
#Fill null values of metascore

# %%
movies_df.describe()
# Out:
#               rank         year      runtime       rating         votes  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000   113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962    18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000   100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000   111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000   123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#        revenue_millions    metascore
# count       1000.000000  1000.000000
# mean          82.956376    58.985043
# std           96.412043    16.634858
# min            0.000000    11.000000
# 25%           17.442500    47.750000
# 50%           60.375000    58.985043
# 75%           99.177500    71.000000
# ...

# %%
movies_df["genre"].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object

# %%
movies_df["genre"].value_counts()       #gives frequency of all values in given columns
# Out:
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Comedy,Horror,Romance       1
# Animation,Action,Comedy     1
# Drama,History,War           1
# Action,Drama,Horror         1
# Adventure,Comedy,Horror     1
# Name: genre, Length: 207, dtype: int64

# %%
movies_df["genre"].value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68d2c9b8339d> in <module>
# ----> 1 movies_df["genre"].value_counts().head(10)
#
# NameError: name 'movies_df' is not defined

# %% [markdown]
# # Corelation

# %%
movies_df.corr()    # relationship between columns i.e directly or indirectly
# Out:
#                       rank      year   runtime    rating     votes  \
# rank              1.000000 -0.261605 -0.221739 -0.219555 -0.283876
# year             -0.261605  1.000000 -0.164900 -0.211219 -0.411904
# runtime          -0.221739 -0.164900  1.000000  0.392214  0.407062
# rating           -0.219555 -0.211219  0.392214  1.000000  0.511537
# votes            -0.283876 -0.411904  0.407062  0.511537  1.000000
# revenue_millions -0.252996 -0.117562  0.247834  0.189527  0.607941
# metascore        -0.185159 -0.076077  0.202239  0.604723  0.318116
#
#                   revenue_millions  metascore
# rank                     -0.252996  -0.185159
# year                     -0.117562  -0.076077
# runtime                   0.247834   0.202239
# rating                    0.189527   0.604723
# votes                     0.607941   0.318116
# revenue_millions          1.000000   0.132304
# metascore                 0.132304   1.000000

# %% [markdown]
# # Indexing & Slicing

# %%
genre_col = movies_df[['genre', 'description']]
print(type(genre_col))
genre_col.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                             genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
#
#                                                                description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...

# %%
#loc:- locates by name

prom1 = movies_df.loc["Prometheus"]
prom1

'''
#.iloc:- locates by index

prom2 = movies_df.iloc[2]
prom2
'''
# Out:
# rank                                                                3
# genre                                                 Horror,Thriller
# description         Three girls are kidnapped by a man with a diag...
# director                                           M. Night Shyamalan
# actors              James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# year                                                             2016
# runtime                                                           117
# rating                                                            7.3
# votes                                                          157606
# revenue_millions                                               138.12
# metascore                                                          62
# Name: Split, dtype: object

# %%
movie_subset = movies_df.loc["Prometheus":"Sing"]
movie_subset

movie_subset = movies_df.iloc[1:4]
movie_subset
# Out:
#             rank                     genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        actors  year  runtime  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012      124
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016      117
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016      108
#
# ...

# %% [markdown]
# # Giving conditions

# %%
movies_df[movies_df["director"] == "Ridley Scott"].head()
# Out:
#                         rank                     genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
#
#                                                               description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
#
#                             director  \
# Title
# Prometheus              Ridley Scott
# The Martian             Ridley Scott
# Robin Hood              Ridley Scott
# ...

# %%
movies_df[movies_df["rating"] > 8].head()
# Out:
#                          rank                    genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
# La La Land                  7       Comedy,Drama,Music
# Hacksaw Ridge              17  Biography,Drama,History
# Lion                       19          Biography,Drama
# Bahubali: The Beginning    27   Action,Adventure,Drama
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Hacksaw Ridge            WWII American Army Medic Desmond T. Doss, who ...
# Lion                     A five-year-old Indian boy gets lost on the st...
# Bahubali: The Beginning  In ancient India, an adventurous and daring ma...
#
#                                 director  \
# Title
# Guardians of the Galaxy       James Gunn
# La La Land               Damien Chazelle
# ...

# %%
movies_df[(movies_df["director"] == "Ridley Scott") | (movies_df["director"] == "Christophe Lourdelet")].head()

#OR

movies_df[movies_df["director"].isin(["Ridley Scott" , "Christophe Lourdelet"])].head()
# Out:
#                    rank                     genre  \
# Title
# Prometheus            2  Adventure,Mystery,Sci-Fi
# Sing                  4   Animation,Comedy,Family
# The Martian         103    Adventure,Drama,Sci-Fi
# Robin Hood          388    Action,Adventure,Drama
# American Gangster   471     Biography,Crime,Drama
#
#                                                          description  \
# Title
# Prometheus         Following clues to the origin of mankind, a te...
# Sing               In a city of humanoid animals, a hustling thea...
# The Martian        An astronaut becomes stranded on Mars after hi...
# Robin Hood         In 12th century England, Robin and his band of...
# American Gangster  In 1970s America, a detective works to bring d...
#
#                                director  \
# Title
# Prometheus                 Ridley Scott
# Sing               Christophe Lourdelet
# The Martian                Ridley Scott
# Robin Hood                 Ridley Scott
# ...

# %%
# Multiple conditions

movies_df[
    ((movies_df["year"] >= 2005) & (movies_df["year"] <= 2010))
    & (movies_df["rating"] > 8)
    & (movies_df["revenue_millions"] < movies_df["revenue_millions"].quantile(0.25))
    ]
# Out:
#                      rank               genre  \
# Title
# 3 Idiots              431        Comedy,Drama
# The Lives of Others   477      Drama,Thriller
# Incendies             714   Drama,Mystery,War
# Taare Zameen Par      992  Drama,Family,Music
#
#                                                            description  \
# Title
# 3 Idiots             Two friends are searching for their long lost ...
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
# Incendies            Twins journey to the Middle East to discover t...
# Taare Zameen Par     An eight-year-old boy is thought to be a lazy ...
#
#                                              director  \
# Title
# 3 Idiots                              Rajkumar Hirani
# The Lives of Others  Florian Henckel von Donnersmarck
# Incendies                            Denis Villeneuve
# Taare Zameen Par                           Aamir Khan
#
# ...

# %% [markdown]
# # Applying Functions

# %%
def rating_func(x):
    if x>=8:
        return "Good"
    else:
        return "Bad"

# %%
movies_df["rating_category"] = movies_df["rating"].apply(rating_func)
movies_df.head(8)

#Or

movies_df["rating_category"] = movies_df["rating"].apply(lambda x : "Good" if x >= 8 else "Bad")
movies_df.head(5)
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %% [markdown]
# # Brief Plotting

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({"font.size" : 20, "figure.figsize" : (10,8)})    #set font and plot

# %%
# For categorial variables utilize barcharts and boxplots. 
# For continuous variables utilize Histogram, Scatterplots, Linegraphs, Boxplots.

# %%
movies_df.plot(kind = "scatter", x = "rating", y = "revenue_millions", title = "Rating vs Revenue_millions")

# %%
movies_df["rating"].plot(kind = "hist", title = "Ratings")

# %%
movies_df.plot(kind = "scatter", x = "rating", y = "votes", title = "Rating vs Votes")

# %%
movies_df.plot(kind = "hist", x = "votes", y = "rating", title = "Rating vs Votes")

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
movies_df["genre_category"] = lb_make.fit_transform(movies_df["genre"])
movies_df[["genre", "genre_category"]].head(8)
# Out:
#                                             genre  genre_category
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi              11
# Prometheus               Adventure,Mystery,Sci-Fi              85
# Split                             Horror,Thriller             195
# Sing                      Animation,Comedy,Family              92
# Suicide Squad            Action,Adventure,Fantasy               7
# The Great Wall           Action,Adventure,Fantasy               7
# La La Land                     Comedy,Drama,Music             116
# Mindhorn                                   Comedy             108

# %%
movies_df["genre_category"].plot(kind = "hist", title = "Genre_hist")

# %%
movies_df.plot(kind = "hist", x = "genre_category", y = "rating", title = "Rating vs Genre_category")

# %%
movies_df["rating"].describe()
# Out:
# count    1000.000000
# mean        6.723200
# std         0.945429
# min         1.900000
# 25%         6.200000
# 50%         6.800000
# 75%         7.400000
# max         9.000000
# Name: rating, dtype: float64

# %%
movies_df["rating"].plot(kind = "box", title = "Ratings")
